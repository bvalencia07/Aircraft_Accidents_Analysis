# %% [markdown]
# # Aircraft Accidents Analysis

# %% [markdown]
# ![Boeing_737.jpg](attachment:Boeing_737.jpg)

# %% [markdown]
# ## Overview

# %% [markdown]
# For this project, the company that I respond to is expanding into new industries to expand their portfolio. Specifically, they are interested in purchasing and operating airplanes for commercial and private enterprises, but do not know anything about the potential risks of aircraft.

# %% [markdown]
# ## Business Problem

# %% [markdown]
# Figure out what aircrafts impose the least amount of risk for both commercial and private use. Charged with determining which aircraft are the lowest risk for the company to start this new business endeavor. Must then translate findings into actionable insights that the head of the new aviation division can use to help decide which aircraft to purchase.

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# This project will consist of working with the [Aviation Dataset](https://www.kaggle.com/datasets/khsamaha/aviation-accident-database-synopses) that consists of a spreadsheet containing information on aircraft accidents over the last few decades. Which includes aircraft make and model, number of fatalities, weather conditions, and more.

# %%
#Import standard packages 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df2 = pd.read_csv('AviationData.csv', encoding='latin1' , low_memory= False)
df2
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88885  20221227106494           Accident      ERA23LA095  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88887  20221227106498           Accident      WPR23LA076  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country   Latitude   Longitude Airport.Code  \
# ...

# %%
#Input functions to retrieve basic knowledge about the dataset
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50249 non-null  object
#  9   Airport.Name            52790 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87572 non-null  object
# ...

# %%
#Find types of engines
df2['Engine.Type'].value_counts()
# Out:
# Reciprocating      69530
# Turbo Shaft         3609
# Turbo Prop          3391
# Turbo Fan           2481
# Unknown             2051
# Turbo Jet            703
# None                  19
# Geared Turbofan       12
# Electric              10
# LR                     2
# NONE                   2
# UNK                    1
# Hybrid Rocket          1
# Name: Engine.Type, dtype: int64

# %%
df2.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       82805.000000          77488.000000            76379.000000
# mean            1.146585              0.647855                0.279881
# std             0.446510              5.485960                1.544084
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            349.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          76956.000000     82977.000000
# mean               0.357061         5.325440
# std                2.235625        27.913634
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# ...

# %%
df2['Total.Fatal.Injuries'].value_counts()
# Out:
# 0.0      59675
# 1.0       8883
# 2.0       5173
# 3.0       1589
# 4.0       1103
#          ...
# 31.0         1
# 169.0        1
# 150.0        1
# 117.0        1
# 156.0        1
# Name: Total.Fatal.Injuries, Length: 125, dtype: int64

# %%
#Drop columns that aren't needed or that may be mostly null
df2cleaned = df2.drop(columns=['Latitude' , 'Longitude'  , 'FAR.Description' , 'Schedule' , 'Air.carrier'])
df2cleaned
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88885  20221227106494           Accident      ERA23LA095  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88887  20221227106498           Accident      WPR23LA076  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country Airport.Code Airport.Name  \
# 0      MOOSE CREEK, ID  United States          NaN          NaN
# ...

# %%
#Review cleaned data
df2cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Airport.Code            50249 non-null  object
#  7   Airport.Name            52790 non-null  object
#  8   Injury.Severity         87889 non-null  object
#  9   Aircraft.damage         85695 non-null  object
#  10  Aircraft.Category       32287 non-null  object
#  11  Registration.Number     87572 non-null  object
#  12  Make                    88826 non-null  object
#  13  Model                   88797 non-null  object
# ...

# %%
df2cleaned['Aircraft.Category'].value_counts()
# Out:
# Airplane             27617
# Helicopter            3440
# Glider                 508
# Balloon                231
# Gyrocraft              173
# Weight-Shift           161
# Powered Parachute       91
# Ultralight              30
# Unknown                 14
# WSFT                     9
# Powered-Lift             5
# Blimp                    4
# UNK                      2
# ULTR                     1
# Rocket                   1
# Name: Aircraft.Category, dtype: int64

# %%
#Filter aircraft category so that I'm only working with airplanes
df_airplane = df2cleaned.loc[df2cleaned['Aircraft.Category']=='Airplane'] 
df_airplane
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 5      20170710X52551           Accident      NYC79AA106  1979-09-17
# 7      20020909X01562           Accident      SEA82DA022  1982-01-01
# 8      20020909X01561           Accident      NYC82DA015  1982-01-01
# 12     20020917X02148           Accident      FTW82FRJ07  1982-01-02
# 13     20020917X02134           Accident      FTW82FRA14  1982-01-02
# ...               ...                ...             ...         ...
# 88869  20221213106455           Accident      WPR23LA065  2022-12-13
# 88873  20221215106463           Accident      ERA23LA090  2022-12-14
# 88876  20221219106475           Accident      WPR23LA069  2022-12-15
# 88877  20221219106470           Accident      ERA23LA091  2022-12-16
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
#
#                Location        Country Airport.Code  \
# 5            BOSTON, MA  United States          NaN
# ...

# %%
#Chart the relationship between reported accidents and number of engines
x = df_airplane['Number.of.Engines'].value_counts().sort_index().index
y = df_airplane['Number.of.Engines'].value_counts().sort_index().values

fig, ax = plt.subplots(figsize=(10,5))
ax.bar(x,y)
ax.set_title('Accidents per Number of Engines')
ax.set_xlabel('Number of Engines')
ax.set_ylabel('Accidents Reported');

# %%
#Get rid of repeating 'Unkown' category
df_airplane['Engine.Type'].replace(to_replace='UNK', value='Unknown', inplace = True)
# Out:
# C:\Users\bryan\anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
#chart relationship between engine types and accidents reported
x = df_airplane['Engine.Type'].value_counts().sort_index().index
y = df_airplane['Engine.Type'].value_counts().sort_index().values

fig, ax = plt.subplots(figsize=(12,5))
ax.bar(x,y)
ax.set_title('Accidents per Airplane Engine Type')
ax.set_xlabel('Types of Airplane Engines')
ax.set_ylabel('Accidents Reported');

# %%
#Get rid of repeating 'UNK' category
df_airplane['Weather.Condition'].replace(to_replace='UNK', value='Unk', inplace = True)

# %%
#chart the relationship between accidents reported and weather conditions
x = df_airplane['Weather.Condition'].value_counts().sort_index().index
y = df_airplane['Weather.Condition'].value_counts().sort_index().values

fig, ax = plt.subplots(figsize=(10,5))
ax.bar(x,y)
ax.set_title('Accidents per Weather Condition')
ax.set_xlabel('Weather Conditions')
ax.set_ylabel('Accidents Reported');

# %% [markdown]
# Filter data to find what airplanes have only two engines and have a turbo fan engine. These aircrafts seem to be the ones that are considered safest / lowest risk.

# %%
df_airplane = df2cleaned.loc[df2cleaned['Number.of.Engines']==2.0] 
df_airplane
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 5      20170710X52551           Accident      NYC79AA106  1979-09-17
# 8      20020909X01561           Accident      NYC82DA015  1982-01-01
# 25     20020917X01905           Accident      DCA82AA008  1982-01-03
# 26     20020917X01720           Accident      ATL82FA033  1982-01-03
# 33     20020917X02254           Accident      LAX82FA038  1982-01-04
# ...               ...                ...             ...         ...
# 88836  20221202106398           Accident      ERA23LA075  2022-11-30
# 88837  20221209106436           Accident      ERA23LA081  2022-12-01
# 88858  20221211106438           Accident      ERA23LA083  2022-12-09
# 88869  20221213106455           Accident      WPR23LA065  2022-12-13
# 88876  20221219106475           Accident      WPR23LA069  2022-12-15
#
#                  Location        Country Airport.Code  \
# 5              BOSTON, MA  United States          NaN
# ...

# %%
#Filter data to only look at aircrafts with Turbo Fans
df_airplane = df2cleaned.loc[df2cleaned['Engine.Type']=='Turbo Fan'] 
df_airplane
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 5      20170710X52551           Accident      NYC79AA106  1979-09-17
# 79     20020917X01897           Incident      CHI82IA026  1982-01-12
# 84     20020917X01907           Accident      DCA82AA011  1982-01-13
# 149    20020917X01767           Incident      ATL82IA041  1982-01-22
# 155    20020917X01909           Accident      DCA82AA013  1982-01-23
# ...               ...                ...             ...         ...
# 87622  20220406104897           Accident      WPR22LA143  2022-04-02
# 87692  20220418104951           Accident      ERA22LA190  2022-04-17
# 87834  20220623105307           Accident      DCA22LA134  2022-05-22
# 88083  20220718105497           Accident      DCA22LA151  2022-07-02
# 88158  20220720105531           Accident      ERA22LA325  2022-07-15
#
#              Location        Country Airport.Code  \
# 5          BOSTON, MA  United States          NaN
# ...

# %%
#Pull only the important columns into a new data frame
df_airplane_models = df_airplane[['Number.of.Engines' , 'Engine.Type' , 'Make', 'Model' , 'Total.Serious.Injuries' ]] 
df_airplane_models.head(20)
# Out:
#       Number.of.Engines Engine.Type               Make          Model  \
# 5                   2.0   Turbo Fan  Mcdonnell Douglas            DC9
# 79                  3.0   Turbo Fan           Lockheed         L-1011
# 84                  2.0   Turbo Fan             Boeing        737-222
# 149                 2.0   Turbo Fan       Dassault/sud      FALCON 20
# 155                 3.0   Turbo Fan  Mcdonnell Douglas       DC-10-30
# 230                 3.0   Turbo Fan  Mcdonnell-douglas       DC-10-10
# 344                 3.0   Turbo Fan             Boeing        727-235
# 506                 4.0   Turbo Fan             Boeing       707-131B
# 522                 2.0   Turbo Fan            Douglas        DC-9-82
# 737                 2.0   Turbo Fan           Rockwell  SABRELINER 65
# 796                 3.0   Turbo Fan             Boeing        727-200
# 901                 3.0   Turbo Fan             Boeing        727-200
# ...

# %%
df_airplane_models
# Out:
#        Number.of.Engines Engine.Type                       Make        Model  \
# 5                    2.0   Turbo Fan          Mcdonnell Douglas          DC9
# 79                   3.0   Turbo Fan                   Lockheed       L-1011
# 84                   2.0   Turbo Fan                     Boeing      737-222
# 149                  2.0   Turbo Fan               Dassault/sud    FALCON 20
# 155                  3.0   Turbo Fan          Mcdonnell Douglas     DC-10-30
# ...                  ...         ...                        ...          ...
# 87622                2.0   Turbo Fan             BOMBARDIER INC  CL-600-2B16
# 87692                2.0   Turbo Fan       TEXTRON AVIATION INC         525B
# 87834                2.0   Turbo Fan                     BOEING      737-700
# 88083                2.0   Turbo Fan                     BOEING      737-700
# 88158                2.0   Turbo Fan  RAYTHEON AIRCRAFT COMPANY         400A
#
#        Total.Serious.Injuries
# ...

# %%
#Filter data to only look at aircrafts with 2 engines
df_cleaned = df_airplane_models.loc[df_airplane_models['Number.of.Engines'] == 2.0]
df_cleaned
# Out:
#        Number.of.Engines Engine.Type                       Make  \
# 5                    2.0   Turbo Fan          Mcdonnell Douglas
# 84                   2.0   Turbo Fan                     Boeing
# 149                  2.0   Turbo Fan               Dassault/sud
# 522                  2.0   Turbo Fan                    Douglas
# 737                  2.0   Turbo Fan                   Rockwell
# ...                  ...         ...                        ...
# 87622                2.0   Turbo Fan             BOMBARDIER INC
# 87692                2.0   Turbo Fan       TEXTRON AVIATION INC
# 87834                2.0   Turbo Fan                     BOEING
# 88083                2.0   Turbo Fan                     BOEING
# 88158                2.0   Turbo Fan  RAYTHEON AIRCRAFT COMPANY
#
#                Model  Total.Serious.Injuries
# 5                DC9                     NaN
# 84           737-222                     6.0
# 149        FALCON 20                     0.0
# ...

# %%
#Find the make and model of airplanes that run on turbo fans that have two engines and
#that also reported zero serious injuries 
df_clean = df_cleaned.loc[df_cleaned['Total.Serious.Injuries'] == 0.0]
df_clean.head(40)
# Out:
#       Number.of.Engines Engine.Type                        Make  \
# 149                 2.0   Turbo Fan                Dassault/sud
# 522                 2.0   Turbo Fan                     Douglas
# 737                 2.0   Turbo Fan                    Rockwell
# 906                 2.0   Turbo Fan                    Rockwell
# 1833                2.0   Turbo Fan                     Douglas
# 2254                2.0   Turbo Fan                      Boeing
# 2335                2.0   Turbo Fan                      Boeing
# 3076                2.0   Turbo Fan                     Douglas
# 3292                2.0   Turbo Fan                      Cessna
# 3392                2.0   Turbo Fan           Mcdonnell Douglas
# 3417                2.0   Turbo Fan                      Boeing
# 3447                2.0   Turbo Fan                      Boeing
# 3454                2.0   Turbo Fan              Gates Lear Jet
# 3510                2.0   Turbo Fan                     Douglas
# ...

# %%
df_clean['Make'].value_counts()
# Out:
# Boeing               198
# BOEING               148
# Mcdonnell Douglas     93
# AIRBUS                71
# CESSNA                65
#                     ...
# HAWKER SIDDELEY        1
# ROCKWELL               1
# Eclipse                1
# Dassault-Breguet       1
# SUKHOI                 1
# Name: Make, Length: 93, dtype: int64

# %%
#clean the Boeing category
df_clean['Make'].replace(to_replace='Boeing', value='BOEING', inplace = True)
df_clean['Make'].replace(to_replace='Boeing Commercial Airplane Gro', value='BOEING', inplace = True)
df_clean['Make'].replace(to_replace='THE BOEING COMPANY', value='BOEING', inplace = True)

# %%
#clean repeating Airbus categories
df_clean['Make'].replace(to_replace='Airbus', value='AIRBUS', inplace = True)

# %%
#clean for Cessna
df_clean['Make'].replace(to_replace='Cessna', value='CESSNA', inplace = True)
df_clean['Make'].replace(to_replace='CESSNA AIRCRAFT COMPANY', value='CESSNA', inplace = True)

# %%
#clean for learjet
df_clean['Make'].replace(to_replace='Learjet', value='LEARJET', inplace = True)
df_clean['Make'].replace(to_replace='LEARJET INC', value='LEARJET', inplace = True)
df_clean['Make'].replace(to_replace='Gates Learjet', value='LEARJET', inplace = True)
df_clean['Make'].replace(to_replace='Gates Lear jet', value='LEARJET', inplace = True)
df_clean['Make'].replace(to_replace='GATES LEAR JET', value='LEARJET', inplace = True)
df_clean['Make'].replace(to_replace='Gates Lear Jet', value='LEARJET', inplace = True)
df_clean['Make'].replace(to_replace='Gates Learjet Corporation', value='LEARJET', inplace = True)
df_clean['Make'].replace(to_replace='GATES LEARJET CORP.', value='LEARJET', inplace = True)

# %%
#clean for Airbus
df_clean['Make'].replace(to_replace='Airbus Industrie', value='AIRBUS', inplace = True)
df_clean['Make'].replace(to_replace='AIRBUS INDUSTRIE', value='AIRBUS', inplace = True)

# %%
df_clean['Make'].replace(to_replace='BOEING COMPANY', value='BOEING', inplace = True)

# %%
#clean for McDonnell Douglas
df_clean['Make'].replace(to_replace='McDonnell Douglas', value='MCDONNELL DOUGLAS', inplace = True)
df_clean['Make'].replace(to_replace='Mcdonnell Douglas', value='MCDONNELL DOUGLAS', inplace = True)
df_clean['Make'].replace(to_replace='MCDONNELL DOUGLAS AIRCRAFT CO', value='MCDONNELL DOUGLAS', inplace = True)
df_clean['Make'].replace(to_replace='MCDONNELL DOUGLAS CORPORATION', value='MCDONNELL DOUGLAS', inplace = True)
df_clean['Make'].replace(to_replace='DOUGLAS', value='MCDONNELL DOUGLAS', inplace = True)
df_clean['Make'].replace(to_replace='Douglas', value='MCDONNELL DOUGLAS', inplace = True)

# %%
#clean for BEECH
df_clean['Make'].replace(to_replace='BEECHCRAFT', value='BEECH', inplace = True)
df_clean['Make'].replace(to_replace='Beech', value='BEECH', inplace = True)
df_clean['Make'].replace(to_replace='Beechcraft', value='BEECH', inplace = True)

# %%
#clean for Dassault
df_clean['Make'].replace(to_replace='DASSAULT/SUD', value='DASSAULT', inplace = True)
df_clean['Make'].replace(to_replace='Dassault', value='DASSAULT', inplace = True)
df_clean['Make'].replace(to_replace='Dassault-Breguet', value='DASSAULT', inplace = True)
df_clean['Make'].replace(to_replace='Dassault-breguet', value='DASSAULT', inplace = True)
df_clean['Make'].replace(to_replace='Dassault/sud', value='DASSAULT', inplace = True)

# %%
#clean for Embraer
df_clean['Make'].replace(to_replace='Embraer', value='EMBRAER', inplace = True)
df_clean['Make'].replace(to_replace='EMBRAER S A', value='EMBRAER', inplace = True)
df_clean['Make'].replace(to_replace='EMBRAER S.A.', value='EMBRAER', inplace = True)
df_clean['Make'].replace(to_replace='EMBRAER-EMPRESA BRASILEIRA DE', value='EMBRAER', inplace = True)

# %%
#clean for Gulfstream
df_clean['Make'].replace(to_replace='Gulfstream', value= 'GULFSTREAM', inplace = True)
df_clean['Make'].replace(to_replace='GULFSTREAM AEROSPACE', value='GULFSTREAM', inplace = True)
df_clean['Make'].replace(to_replace='GULFSTREAM AMERICAN CORP.', value='GULFSTREAM', inplace = True)
df_clean['Make'].replace(to_replace='Gulfstream Aerospace', value='GULFSTREAM', inplace = True)
df_clean['Make'].replace(to_replace='Gulfstream Aerospace Corp.', value='GULFSTREAM', inplace = True)

# %%
#clean for Grumman
df_clean['Make'].replace(to_replace='Grumman American', value='Grumman', inplace = True)
df_clean['Make'].replace(to_replace='GRUMMAN AMERICAN AVN. CORP.', value='Grumman', inplace = True)

# %%
#clean for Rockwell
df_clean['Make'].replace(to_replace='Hawker Siddeley', value='HAWKER SIDDELEY', inplace = True)
df_clean['Make'].replace(to_replace='Hawker Beechcraft', value='HAWKER BEECHCRAFT CORP', inplace = True)
df_clean['Make'].replace(to_replace='HAWKER BEECHCRAFT CORPORATION', value='HAWKER BEECHCRAFT CORP', inplace = True)
df_clean['Make'].replace(to_replace='Rockwell', value='ROCKWELL', inplace = True)

# %%
#Clean for IAI
df_clean['Make'].replace(to_replace='ISRAEL AIRCRAFT INDUSTRIES', value='IAI', inplace = True)
df_clean['Make'].replace(to_replace='Israel Aircraft Industries', value='IAI', inplace = True)
df_clean['Make'].replace(to_replace='Bae', value='BAE', inplace = True)
df_clean['Make'].replace(to_replace='BOMBARDIER INC', value='BOMBARDIER', inplace = True)
df_clean['Make'].replace(to_replace='Bombardier', value='BOMBARDIER', inplace = True)
df_clean['Make'].replace(to_replace='Bombardier, Inc.', value='BOMBARDIER', inplace = True)
df_clean['Make'].replace(to_replace='BOMBARDIER LEARJET CORP.', value='BOMBARDIER', inplace = True)

# %%
#clean for Raytheon
df_clean['Make'].replace(to_replace='Raytheon', value='RAYTHEON', inplace = True)
df_clean['Make'].replace(to_replace='RAYTHEON AIRCRAFT COMPANY', value='RAYTHEON', inplace = True)
df_clean['Make'].replace(to_replace='RAYTHEON CORPORATE JETS INC', value='RAYTHEON', inplace = True)
df_clean['Make'].replace(to_replace='Raytheon Corporate Jets', value='RAYTHEON', inplace = True)

# %%
#clean for Canadair
df_clean['Make'].replace(to_replace='Canadair', value='CANADAIR', inplace = True)
df_clean['Make'].replace(to_replace='CANADAIR LTD', value='CANADAIR', inplace = True)
df_clean['Make'].replace(to_replace='British Aerospace', value='BRITISH AEROSPACE', inplace = True)
df_clean['Make'].replace(to_replace='British Aircraft Corp. (bac)', value='BRITISH AEROSPACE', inplace = True)

# %%
#clean for eclipse
df_clean['Make'].replace(to_replace='Eclipse', value='ECLIPSE AVIATION CORP', inplace = True)
df_clean['Make'].replace(to_replace='Eclipse Aviation Corporation', value='ECLIPSE AVIATION CORP', inplace = True)

# %%
#clean for Rockwell
df_clean['Make'].replace(to_replace='North American', value='ROCKWELL', inplace = True)
df_clean['Make'].replace(to_replace='Rockwell International', value='ROCKWELL', inplace = True)
df_clean['Make'].replace(to_replace='North American Rockwell Corp.', value='ROCKWELL', inplace = True)

# %%
#Graph the relationship between aircraft makes and accidents reporting zero injuries
x = df_clean['Make'].value_counts().sort_index().index
y = df_clean['Make'].value_counts().sort_index().values

fig, ax = plt.subplots(figsize=(15,5))
ax.bar(x,y)
ax.set_title('Most Reliable Aircraft Makes')
ax.set_xlabel('Aircraft Makes')
ax.set_ylabel('Accidents Reporting Zero Injuries')
plt.xticks(rotation=90);

# %% [markdown]
# ## Results

# %% [markdown]
# Upon examining the dataset, one is able to notice that single engine aircrafts and reciprocating engine types have the highest number of reported accidents within the dataset. While aiplanes with two engines and that ran on turbo fans appeared to be the safest. With that knowledge in mind, one is able to further find that airplanes that come from the Boeing brand seem to be the most reappearing airplanes that reported back zero serious injuries.

# %% [markdown]
# ## Tableau

# %% [markdown]
# For further visual understanding of the dataset, visit [tableau](https://public.tableau.com/app/profile/bryan.valencia5690/viz/AviationAnalysis_17040920392270/AviationDashboard?publish=yes)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In conclusion, the stakeholders should avoid single engine reciprocating aircrafts as those are considered to have the highest risk and should turn to turbo fan aircrafts with two engines, specifically those manufactured by Boeing as those would be the lowest risk. That being said, I would recommend the Boeing 737 and Boeing 777 for commercial use, and the Learjet 35 for private use.

# %% [markdown]
# ![Learjet_35.jpg](attachment:Learjet_35.jpg)
